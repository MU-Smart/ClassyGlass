# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt# scipy
import scipy
import seaborn as sns
# scikit-learn
import sklearn
from pandas.plotting import scatter_matrix
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
#from sklearn.neural_network import MLPClassifier
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

# %%
fileList = pd.read_csv("Selected_Feature_V0.csv", index_col=0)

# %%
fileList  = fileList[fileList["22"]!=6].copy()

# %%
X = fileList[fileList.columns[:-1]]

# %%
print (X)
# Out:
#              0         1        2         3        4         5          6  \
# 0     -0.98099  0.000057 -0.20195  0.000057 -0.20195  0.000057 -34.957000
# 1     -0.97937  0.000025 -0.20509  0.000025 -0.20509  0.000016 -34.955667
# 2     -0.99545  0.006806 -0.15962  0.006806 -0.15962  0.006339 -34.198667
# 3     -1.01098  0.009715 -0.08560  0.009715 -0.08560  0.004819 -34.302000
# 4     -1.01176  0.000288 -0.06231  0.000288 -0.06231  0.000092 -34.938667
# ...        ...       ...      ...       ...      ...       ...        ...
# 40646 -0.57926  0.050269  0.24143  0.050269  0.24143  0.003072 -30.171667
# 40647 -1.12174  0.005711  0.33634  0.005711  0.33634  0.012937 -40.020333
# 40648 -0.99728  0.006817  0.41937  0.006817  0.41937  0.003702 -36.308333
# 40649 -0.42855  0.028404  0.33505  0.028404  0.33505  0.006891 -26.705333
# 40650 -0.13950  0.013534  0.27469  0.013534  0.27469  0.000687 -26.223000
#
#                7            8            9  ...           12        13  \
# ...

# %%
y = fileList['22']

# %%
print(y)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 40646    5
# 40647    5
# 40648    5
# 40649    5
# 40650    5
# Name: 22, Length: 40651, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state=123)

# %%
X_train
# Out:
#              0         1        2         3        4         5          6  \
# 8380   0.04198  0.003409  0.03952  0.003409  0.03952  0.000567 -31.653000
# 29412 -0.38079  0.060199  0.11912  0.060199  0.11912  0.003878  26.454667
# 26935 -0.94292  0.000709 -0.08364  0.000709 -0.08364  0.000347 -22.447667
# 23885  0.00740  0.027545 -0.18961  0.027545 -0.18961  0.001742 -41.726667
# 29183 -0.93468  0.010181 -0.00042  0.010181 -0.00042  0.003624 -18.783333
# ...        ...       ...      ...       ...      ...       ...        ...
# 7763  -0.40681  0.000272  0.09966  0.000272  0.09966  0.000047 -42.298333
# 15377  0.12092  0.000020  0.07743  0.000020  0.07743  0.000016 -27.601000
# 17730 -0.30852  0.000106 -0.00704  0.000106 -0.00704  0.000191 -43.828667
# 28030 -0.89111  0.018459  0.00714  0.018459  0.00714  0.021345 -15.734000
# 15725 -0.24159  0.018116 -0.03750  0.018116 -0.03750  0.013641 -43.365667
#
#                7            8            9  ...           12        13  \
# ...

# %%
X_test
# Out:
#              0         1        2         3        4         5          6  \
# 18617 -0.41213  0.000026  0.01914  0.000026  0.01914  0.000009 -45.138333
# 33245 -0.79150  0.025309  0.24368  0.025309  0.24368  0.002897 -41.035000
# 40649 -0.42855  0.028404  0.33505  0.028404  0.33505  0.006891 -26.705333
# 34323 -0.34979  0.014850  0.08973  0.014850  0.08973  0.007495 -38.153000
# 27469 -0.92245  0.000016 -0.03823  0.000016 -0.03823  0.000017 -18.558667
# ...        ...       ...      ...       ...      ...       ...        ...
# 15077  0.87983  0.005138  0.02426  0.005138  0.02426  0.017853  40.218667
# 2083  -0.22839  0.000045 -0.00309  0.000045 -0.00309  0.000126 -41.387667
# 7697  -0.42894  0.000135  0.10445  0.000135  0.10445  0.000082 -42.527333
# 29333 -0.88292  0.008319 -0.04695  0.008319 -0.04695  0.018757 -14.390000
# 4589  -0.43424  0.000433  0.48389  0.000433  0.48389  0.000314 -25.960667
#
#                7            8            9  ...          12        13  \
# ...

# %%
# Reduced parameter grid for faster GridSearchCV
rfc_params = {
    'bootstrap': [True],
    'max_depth': [10, 50],            
    'min_samples_split': [12],       
    'n_estimators': [50, 125]         
}
gbc_params = {
    'max_depth': [10, 50],            
    "min_samples_split": [12],       
    "learning_rate": [0.1],           
    'n_estimators': [50, 125]         
}

# %%
gbc_grcv = GridSearchCV(GradientBoostingClassifier(), param_grid=gbc_params, refit=True, n_jobs=-1)

# %%
print(gbc_grcv.fit(X_train, y_train))
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.1], 'max_depth': [10, 50],
#                          'min_samples_split': [12], 'n_estimators': [50, 125]})

# %%
gbc_grcv.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 50,
#  'min_samples_split': 12,
#  'n_estimators': 125}

# %%
# Gradient Boosting 
cross_val_score(GradientBoostingClassifier(learning_rate=0.1, 
                                           max_depth=50, 
                                           max_features=12, 
                                           min_samples_split=12, 
                                           n_estimators=125),
               X_train, y_train, cv=5, n_jobs=-1)
# Out:
# array([0.83856089, 0.83379459, 0.83579336, 0.84117466, 0.83410209])

# %%
XGB_params = {
        'min_child_weight': [1, 10],
        'gamma': [0.5, 1.5],
        'subsample': [0.6, 1.0],
        'colsample_bytree': [0.6, 1.0],
        'max_depth': [3, 5]
        }

# %%
xgb = XGBClassifier(learning_rate=0.02, n_estimators=600, objective='binary:logistic',
                    silent=True, nthread=1)

# %%
y_train = y_train - 1
y_test = y_test - 1

# %%
folds = 5
param_comb = 3

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 1001)

random_search = RandomizedSearchCV(xgb, param_distributions=XGB_params, n_iter=param_comb, scoring='roc_auc', n_jobs=4, cv=skf.split(X_train, y_train), verbose=3, random_state=1001 )

# Here we go
#start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(X_train.values, y_train)
#timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# /opt/miniconda3/envs/ml/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [14:11:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/envs/ml/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [14:11:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/miniconda3/envs/ml/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [14:11:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
print('\n All results:')
print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
results = pd.DataFrame(random_search.cv_results_)
results.to_csv('xgb-random-grid-search-results-01.csv', index=False)
# Out:
#  All results:
# {'mean_fit_time': array([38.23288655, 34.69155545, 30.82420001]), 'std_fit_time': array([8.2389836 , 7.56524583, 4.93173817]), 'mean_score_time': array([1.87301617, 0.48630633, 0.6512434 ]), 'std_score_time': array([0.53860941, 0.10668441, 0.19309949]), 'param_subsample': masked_array(data=[1.0, 1.0, 0.6],
#              mask=[False, False, False],
#        fill_value=1e+20), 'param_min_child_weight': masked_array(data=[10, 1, 10],
#              mask=[False, False, False],
#        fill_value=999999), 'param_max_depth': masked_array(data=[5, 3, 5],
#              mask=[False, False, False],
#        fill_value=999999), 'param_gamma': masked_array(data=[0.5, 0.5, 1.5],
#              mask=[False, False, False],
#        fill_value=1e+20), 'param_colsample_bytree': masked_array(data=[1.0, 1.0, 1.0],
#              mask=[False, False, False],
# ...

# %%
y_test = random_search.predict_proba(y)
#results_df = pd.DataFrame(data={'id':test_df['id'], 'target':y_test[:,1]})
#results_df.to_csv('submission-random-grid-search-xgb-porto-01.csv', index=False)
print(y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 y_test = random_search.predict_proba(y)
#       2 #results_df = pd.DataFrame(data={'id':test_df['id'], 'target':y_test[:,1]})
#       3 #results_df.to_csv('submission-random-grid-search-xgb-porto-01.csv', index=False)
#       4 print(y_test)
#
# File /opt/miniconda3/envs/ml/lib/python3.12/site-packages/sklearn/model_selection/_search.py:621, in BaseSearchCV.predict_proba(self, X)
#     602 """Call predict_proba on the estimator with the best found parameters.
#     603
#     604 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     618     to that in the fitted attribute :term:`classes_`.
#     619 """
#     620 check_is_fitted(self)
# --> 621 return self.best_estimator_.predict_proba(X)
#
# ...
