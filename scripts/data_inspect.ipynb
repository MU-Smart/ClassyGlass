# %%
import pandas as pd

# %%
df = pd.read_csv("exports/labeled_Dataset_1A.csv")
print(df.head())
# Out:
#       dataset  user_id  experiment_id  activity_label activity    sensor_type  \
# 0  Dataset_1A        1             10              10  Running  Accelerometer
# 1  Dataset_1A        1             10              10  Running  Accelerometer
# 2  Dataset_1A        1             10              10  Running  Accelerometer
# 3  Dataset_1A        1             10              10  Running  Accelerometer
# 4  Dataset_1A        1             10              10  Running  Accelerometer
#
#         epoch_ms  elapsed_s  x-axis (g)  y-axis (g)  z-axis (g)  \
# 0  1568492160270       0.00   -0.006730   -0.011144   -0.017300
# 1  1568492160280       0.01   -0.006833   -0.007291   -0.023945
# 2  1568492160290       0.02   -0.008346   -0.009875   -0.027415
# 3  1568492160300       0.03   -0.010538   -0.014925   -0.028117
# 4  1568492160310       0.04   -0.011649   -0.015300   -0.028354
#
#    x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)  x-axis (T)  y-axis (T)  \
# ...
